# %% [markdown]
# # Drafts notebook

# %% [markdown]
# ## Introduction and aim

# %% [markdown]
# In this notebook I will write all the examples, trials and (probably) mistakes I will do while studying for the course Statistical Techniques and Analysis Methods for Experimental Physics (if I ever will). I aim at having an organised script, even if what I will write in it will be basically garbage.
# I believe that a topic-wise organisation requires to foresee the future, as I can't predict which problems I will face in one week, or even in one day. So I propose to divide the notebook in a chronological order, where every week (starting from Tuesday included and ending with Monday included) will form a separate chapter. Inside of it, it would be good practice to use subheaders specifying the topics that are covered there.

# %% [markdown]
# As of now everything seems to be setted up: GitLab is linked, the repository is cloned, the branch is set to the most updated one, micromamba has been installed and it already created the environment for the course. However, the environment was somehow created in

# %% [raw]
# /opt/homebrew/envs/STAMET-FS25

# %% [markdown]
# so every time I want to activate it I need to run the following line

# %% [raw]
# micromamba activate /opt/homebrew/envs/STAMET-FS25

# %% [markdown]
# I found out that the micromamba environment can be activated irrespective of the current terminal directoy and the command _jupyter notebook_ it will indeed open the environment (which looks like a web page) in that very directory. So, not to mess things up, I resolved to open it only when I'm in the right folder.

# %% [markdown]
# ## Week 1
